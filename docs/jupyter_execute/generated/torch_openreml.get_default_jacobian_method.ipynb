# %%
from torch_openreml.config import get_default_jacobian_method

get_default_jacobian_method()
# Out:
# <function torch.func.jacfwd(func: 'Callable[..., Any]', argnums: 'argnums_t' = 0, has_aux: 'bool' = False, *, randomness: 'str' = 'error') -> 'Callable[..., Any]'>
