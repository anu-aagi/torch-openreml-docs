# %%
import torch
from torch_openreml.covariance import DiagonalMatrix, CovariancePropagation

n, q = 6, 3
z = torch.randn(n, q)
g = DiagonalMatrix(q)
op = CovariancePropagation(z=z, g=g)
params = torch.tensor([0.0, 0.5, 1.0])
op(params)
# Out:
# tensor([[ 4.8619e+00, -8.0081e+00,  2.6579e+00,  1.2687e+01, -1.0183e+01,
#           3.9094e-02],
#         [-8.0081e+00,  1.6861e+01, -6.2301e+00, -3.1213e+01,  2.3988e+01,
#           7.2918e-01],
#         [ 2.6579e+00, -6.2301e+00,  2.8043e+00,  1.2062e+01, -7.3615e+00,
#          -1.6022e+00],
#         [ 1.2687e+01, -3.1213e+01,  1.2062e+01,  6.2114e+01, -4.7205e+01,
#          -1.8946e+00],
#         [-1.0183e+01,  2.3988e+01, -7.3615e+00, -4.7205e+01,  4.3696e+01,
#          -3.9420e+00],
#         [ 3.9094e-02,  7.2918e-01, -1.6022e+00, -1.8946e+00, -3.9420e+00,
#           3.7622e+00]])
