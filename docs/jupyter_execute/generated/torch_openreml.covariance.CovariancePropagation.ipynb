# %%
import torch
from torch_openreml.covariance import DiagonalMatrix, CovariancePropagation

n, q = 6, 3
z = torch.randn(n, q)
g = DiagonalMatrix(q)
op = CovariancePropagation(z=z, g=g)
free_params = torch.tensor([0.0, 0.5, 1.0])
op(free_params)
# Out:
# tensor([[  8.2738,  -0.3780,   8.7021,  -2.4227,   8.3673, -12.2267],
#         [ -0.3780,   2.5194,  -0.9746,   2.0007,   0.6652,  -6.1771],
#         [  8.7021,  -0.9746,   9.3111,  -3.0421,   8.6791, -11.1317],
#         [ -2.4227,   2.0007,  -3.0421,   2.2698,  -1.9335,  -1.9066],
#         [  8.3673,   0.6652,   8.6791,  -1.9335,   9.4682, -14.3597],
#         [-12.2267,  -6.1771, -11.1317,  -1.9066, -14.3597,  37.3994]])
