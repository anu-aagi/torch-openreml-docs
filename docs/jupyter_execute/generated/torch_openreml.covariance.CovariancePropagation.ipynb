# %%
import torch
from torch_openreml.covariance import DiagonalMatrix, CovariancePropagation

n, q = 6, 3
z = torch.randn(n, q)
g = DiagonalMatrix(q)
op = CovariancePropagation(z=z, g=g)
free_params = torch.tensor([0.0, 0.5, 1.0])
op(free_params)
# Out:
# tensor([[ 3.5151e+01,  8.9819e+00, -2.5513e+01, -1.1194e+01,  4.2398e+00,
#          -1.6910e+00],
#         [ 8.9819e+00,  9.5860e+00, -1.3116e+01,  3.9637e-01,  9.8037e-01,
#          -9.6180e-01],
#         [-2.5513e+01, -1.3116e+01,  2.4530e+01,  5.0406e+00, -3.0777e+00,
#           1.6210e+00],
#         [-1.1194e+01,  3.9637e-01,  5.0406e+00,  5.4577e+00, -1.0968e+00,
#           5.7579e-01],
#         [ 4.2398e+00,  9.8037e-01, -3.0777e+00, -1.0968e+00,  7.1716e-01,
#          -9.5215e-03],
#         [-1.6910e+00, -9.6180e-01,  1.6210e+00,  5.7579e-01, -9.5215e-03,
#           2.9091e-01]])
