# %%
import torch
from torch_openreml.covariance import CompoundSymmetricMatrix

mat = CompoundSymmetricMatrix(3)
mat
# Out:
# CompoundSymmetricMatrix(shape=(3, 3), param_specs={'sigma^2': {'fixed': False, 'default': tensor([0.]), 'trans': TransformExpPow2()}, 'rho': {'fixed': False, 'default': tensor([0.]), 'trans': TransformChain([TransformSigmoid(), TransformScaleShift(a=1.5, b=-0.5)])}})

# %%
free_params = torch.tensor([0.5, 0.0])
mat(free_params)
# Out:
# tensor([[2.7183, 0.6796, 0.6796],
#         [0.6796, 2.7183, 0.6796],
#         [0.6796, 0.6796, 2.7183]])

# %%
mat.grad(free_params)
# Out:
# (tensor([[[5.4366, 1.3591, 1.3591],
#           [1.3591, 5.4366, 1.3591],
#           [1.3591, 1.3591, 5.4366]],
#
#          [[0.0000, 1.0194, 1.0194],
#           [1.0194, 0.0000, 1.0194],
#           [1.0194, 1.0194, 0.0000]]]),
#  ['sigma^2', 'rho'])
