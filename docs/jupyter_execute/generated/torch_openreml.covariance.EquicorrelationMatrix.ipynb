# %%
import torch
from torch_openreml.covariance import EquicorrelationMatrix

mat = EquicorrelationMatrix(3)
mat
# Out:
# EquicorrelationMatrix(shape=(3, 3), param_specs={'rho': {'fixed': False, 'default': tensor([0.]), 'trans': TransformChain([TransformSigmoid(), TransformScaleShift(a=1.5, b=-0.5)])}})

# %%
free_params = torch.tensor([0.0])
mat(free_params)
# Out:
# tensor([[1.0000, 0.2500, 0.2500],
#         [0.2500, 1.0000, 0.2500],
#         [0.2500, 0.2500, 1.0000]])

# %%
mat.grad(free_params)
# Out:
# (tensor([[[0.0000, 0.3750, 0.3750],
#           [0.3750, 0.0000, 0.3750],
#           [0.3750, 0.3750, 0.0000]]]),
#  ['rho'])
