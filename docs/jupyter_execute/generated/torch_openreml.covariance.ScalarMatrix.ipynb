# %%
import torch
from torch_openreml.covariance import ScalarMatrix

mat = ScalarMatrix(3)
mat
# Out:
# ScalarMatrix(shape=(3, 3), param_specs={'sigma^2': {'fixed': False, 'default': tensor([0.]), 'trans': TransformExpPow2()}})

# %%
free_params = torch.tensor([0.5])
mat(free_params)
# Out:
# tensor([[2.7183, 0.0000, 0.0000],
#         [0.0000, 2.7183, 0.0000],
#         [0.0000, 0.0000, 2.7183]])

# %%
mat.grad(free_params)
# Out:
# (tensor([[[5.4366, 0.0000, 0.0000],
#           [0.0000, 5.4366, 0.0000],
#           [0.0000, 0.0000, 5.4366]]]),
#  ['sigma^2'])
