# %%
import torch
from torch_openreml import MarginalREML
from torch_openreml.covariance import ScalarMatrix

n, p = 50, 2
y = torch.randn(n)
x = torch.randn(n, p)
theta = torch.tensor([0.0])

mat = ScalarMatrix(n)
reml = MarginalREML(mat)
theta_hat, beta_hat, n_iter = reml.optimize(y, x, theta, verbose=2)
theta_hat, beta_hat
# Out:
#  ⏱ 00:00 | ⚡ ?it/s
# /Users/patrickli/Desktop/rproj/torch-openreml/torch_openreml/marginal_reml.py:391: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4323.)
#   matrix["AI"] = 0.5 * (tensor3d["Y^T P dV"].squeeze() @ tensor3d["P dV P Y"].squeeze().T)
# Iter 1:  ⏱ 00:00 | ⚡ ?it/s
# Iter 1:  ⏱ 00:00 | ⚡ 45.50it/s
# Iter 1:  ⏱ 00:00 | ⚡ 44.37it/s
# Iter 2:  ⏱ 00:00 | ⚡ 41.54it/s
# Iter 2:  ⏱ 00:00 | ⚡ 80.97it/s
# Iter 3:  ⏱ 00:00 | ⚡ 77.64it/s
# Iter 3:  ⏱ 00:00 | ⚡ 114.19it/s
# Iter 4:  ⏱ 00:00 | ⚡ 109.16it/s
# Iter 4:  ⏱ 00:00 | ⚡ 142.85it/s
# Iter 4:  ⏱ 00:00 | ⚡ 139.45it/s
# Iter 4:  ⏱ 00:00 | ⚡ 137.35it/s
# Iter 4:  ⏱ 00:00 | ⚡ 136.55it/s
# ∥∇∥:      10.3691, ∥Δ∥: 0.0888, η: 1.00, ∥Δᶜ∥: 0.0888, log 𝓛: -33.2811
# ∥∇∥:       0.8688, ∥Δ∥: 0.0089, η: 1.00, ∥Δᶜ∥: 0.0089, log 𝓛: -32.7945 (+0.4866)
# ∥∇∥:       0.0077, ∥Δ∥: 0.0001, η: 1.00, ∥Δᶜ∥: 0.0001, log 𝓛: -32.7906 (+0.0039)
# ∥∇∥:       0.0000, ∥Δ∥: 0.0000, η: 1.00, ∥Δᶜ∥: 0.0000, log 𝓛: -32.7906 (+0.0000)
#
# [∇: score, Δ: 𝐉⁻¹∇, η: learning rate, Δᶜ: clip(𝛉 + ηΔ, lb, ub) - 𝛉, 𝓛: restricted likelihood]
#
# ✓ Converged at iteration 4
# (tensor([0.0978]), tensor([-0.0870, -0.1025]))
