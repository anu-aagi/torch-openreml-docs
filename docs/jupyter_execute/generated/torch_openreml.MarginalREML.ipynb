# %%
import torch
from torch_openreml import MarginalREML
from torch_openreml.covariance import ScalarMatrix

n, p = 50, 2
y = torch.randn(n)
x = torch.randn(n, p)
theta = torch.tensor([0.0])

mat = ScalarMatrix(n)
reml = MarginalREML(mat)
theta_hat, beta_hat, n_iter = reml.optimize(y, x, theta, verbose=2)
theta_hat, beta_hat
# Out:
#  ⏱ 00:00 | ⚡ ?it/s
# /Users/patrickli/Desktop/rproj/torch-openreml/torch_openreml/marginal_reml.py:276: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4323.)
#   matrix["AI"] = 0.5 * (tensor3d["Y^T P dV"].squeeze() @ tensor3d["P dV P Y"].squeeze().T)
# Iter 1:  ⏱ 00:00 | ⚡ ?it/s
# Iter 1:  ⏱ 00:00 | ⚡ 37.65it/s
# Iter 1:  ⏱ 00:00 | ⚡ 36.92it/s
# Iter 2:  ⏱ 00:00 | ⚡ 34.96it/s
# Iter 2:  ⏱ 00:00 | ⚡ 68.52it/s
# Iter 3:  ⏱ 00:00 | ⚡ 65.92it/s
# Iter 3:  ⏱ 00:00 | ⚡ 97.12it/s
# Iter 4:  ⏱ 00:00 | ⚡ 93.88it/s
# Iter 4:  ⏱ 00:00 | ⚡ 122.63it/s
# Iter 4:  ⏱ 00:00 | ⚡ 120.51it/s
# Iter 4:  ⏱ 00:00 | ⚡ 119.05it/s
# Iter 4:  ⏱ 00:00 | ⚡ 118.52it/s
# ∥∇∥:       8.8570, ∥Δ∥: 0.0779, η: 1.00, ∥Δᶜ∥: 0.0779, log 𝓛: -32.2782
# ∥∇∥:       0.6554, ∥Δ∥: 0.0067, η: 1.00, ∥Δᶜ∥: 0.0067, log 𝓛: -31.9160 (+0.3622)
# ∥∇∥:       0.0044, ∥Δ∥: 0.0000, η: 1.00, ∥Δᶜ∥: 0.0000, log 𝓛: -31.9138 (+0.0022)
# ∥∇∥:       0.0000, ∥Δ∥: 0.0000, η: 1.00, ∥Δᶜ∥: 0.0000, log 𝓛: -31.9138 (+0.0000)
#
# [∇: score, Δ: 𝐉⁻¹∇, η: learning rate, Δᶜ: clip(𝛉 + ηΔ, lb, ub) - 𝛉, 𝓛: restricted likelihood]
#
# ✓ Converged at iteration 4
# (tensor([0.0847]), tensor([ 0.0732, -0.0255]))
