# %%
import torch
from torch_openreml import MarginalREML
from torch_openreml.covariance import ScalarMatrix

n, p = 50, 2
y = torch.randn(n)
x = torch.randn(n, p)
theta = torch.tensor([0.0])

mat = ScalarMatrix(n)
reml = MarginalREML(mat)
theta_hat, beta_hat, n_iter = reml.optimize(y, x, theta, verbose=2)
theta_hat, beta_hat
# Out:
#  ⏱ 00:00 | ⚡ ?it/s
# /Users/patrickli/Desktop/rproj/torch-openreml/torch_openreml/marginal_reml.py:392: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4323.)
#   matrix["AI"] = 0.5 * (tensor3d["Y^T P dV"].squeeze() @ tensor3d["P dV P Y"].squeeze().T)
# Iter 1:  ⏱ 00:00 | ⚡ ?it/s
# Iter 1:  ⏱ 00:00 | ⚡ 50.89it/s
# Iter 1:  ⏱ 00:00 | ⚡ 49.27it/s
# Iter 2:  ⏱ 00:00 | ⚡ 45.94it/s
# Iter 2:  ⏱ 00:00 | ⚡ 89.43it/s
# Iter 3:  ⏱ 00:00 | ⚡ 85.14it/s
# Iter 3:  ⏱ 00:00 | ⚡ 124.61it/s
# Iter 4:  ⏱ 00:00 | ⚡ 119.62it/s
# Iter 4:  ⏱ 00:00 | ⚡ 155.25it/s
# Iter 4:  ⏱ 00:00 | ⚡ 150.06it/s
# Iter 4:  ⏱ 00:00 | ⚡ 147.75it/s
# Iter 4:  ⏱ 00:00 | ⚡ 146.94it/s
# ∥∇∥:       6.8240, ∥Δ∥: 0.0622, η: 1.00, ∥Δᶜ∥: 0.0622, log 𝓛: -31.4145
# ∥∇∥:       0.4076, ∥Δ∥: 0.0042, η: 1.00, ∥Δᶜ∥: 0.0042, log 𝓛: -31.1936 (+0.2209)
# ∥∇∥:       0.0017, ∥Δ∥: 0.0000, η: 1.00, ∥Δᶜ∥: 0.0000, log 𝓛: -31.1927 (+0.0009)
# ∥∇∥:       0.0000, ∥Δ∥: 0.0000, η: 1.00, ∥Δᶜ∥: 0.0000, log 𝓛: -31.1927 (+0.0000)
#
# [∇: score, Δ: 𝐉⁻¹∇, η: learning rate, Δᶜ: clip(𝛉 + ηΔ, lb, ub) - 𝛉, 𝓛: restricted likelihood]
#
# ✓ Converged at iteration 4
# (tensor([0.0665]), tensor([ 0.2100, -0.0443]))
