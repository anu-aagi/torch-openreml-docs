# %%
import torch
from torch_openreml.covariance import DiagonalMatrix

mat = DiagonalMatrix(3)
mat
# Out:
# DiagonalMatrix(shape=(3, 3), param_specs={'sigma^2_0': {'fixed': False, 'default': tensor([0.]), 'trans': TransformExpPow2()}, ..., 'sigma^2_2': {'fixed': False, 'default': tensor([0.]), 'trans': TransformExpPow2()}})

# %%
free_params = torch.tensor([0.0, 0.5, 1.0])
mat(free_params)
# Out:
# tensor([[1.0000, 0.0000, 0.0000],
#         [0.0000, 2.7183, 0.0000],
#         [0.0000, 0.0000, 7.3891]])

# %%
mat.grad(free_params)
# Out:
# (tensor([[[ 2.0000,  0.0000,  0.0000],
#           [ 0.0000,  5.4366,  0.0000],
#           [ 0.0000,  0.0000, 14.7781]],
#
#          [[ 2.0000,  0.0000,  0.0000],
#           [ 0.0000,  5.4366,  0.0000],
#           [ 0.0000,  0.0000, 14.7781]],
#
#          [[ 2.0000,  0.0000,  0.0000],
#           [ 0.0000,  5.4366,  0.0000],
#           [ 0.0000,  0.0000, 14.7781]]]),
#  ['sigma^2_0', 'sigma^2_1', 'sigma^2_2'])
